# %%
import os
import glob
import pandas
import seaborn as sns
import matplotlib.pyplot as plt, mpld3

# %%
path_datasets_dir = r'./datasets'
path_datasets_files = glob.glob(path_datasets_dir + "/*.csv")
path_datasets_files
# Out:
# ['./datasets/2022-06-05.csv',
#  './datasets/2022-06-08.csv',
#  './datasets/2022-06-09.csv',
#  './datasets/2022-06-04.csv',
#  './datasets/2022-06-03.csv',
#  './datasets/2022-06-07.csv',
#  './datasets/2022-06-06.csv',
#  './datasets/2022-06-10.csv']

# %%
dfs = []

for path_datasets_file in path_datasets_files:
    df_temp = pandas.read_csv(path_datasets_file)
    dfs.append(df_temp)

df = pandas.concat(dfs)
df = df.sort_values('current_date')
df
# Out:
#       Unnamed: 0 current_date  category_id              category_name  \
# 1              1   2022-06-03           12  Aceite, especias y salsas
# 2317        2317   2022-06-03            4       Charcutería y quesos
# 2318        2318   2022-06-03            4       Charcutería y quesos
# 2319        2319   2022-06-03            4       Charcutería y quesos
# 2320        2320   2022-06-03            4       Charcutería y quesos
# ...          ...          ...          ...                        ...
# 2318        2318   2022-06-10            4       Charcutería y quesos
# 2317        2317   2022-06-10            4       Charcutería y quesos
# 2316        2316   2022-06-10            4       Charcutería y quesos
# 2327        2327   2022-06-10            4       Charcutería y quesos
# 6970        6970   2022-06-10           10                      Zumos
#
#       subcategory_id        subcategory_name  product_id  \
# 1                112   Aceite, vinagre y sal     19715.0
# 2317              50           Jamón serrano     58278.0
# 2318              50           Jamón serrano     58280.0
# 2319              50           Jamón serrano     59173.0
# 2320              50           Jamón serrano     58230.0
# ...              ...                     ...         ...
# 2318              50           Jamón serrano     58280.0
# 2317              50           Jamón serrano     58278.0
# 2316              50           Jamón serrano     58110.0
# 2327              58        Paté y sobrasada     52337.0
# 6970              98  Tomate y otros sabores     39390.0
#
#                                      product_name  price_unit  price_bulk  \
# 1                           Sal de mesa Hacendado        0.38        1.52
# 2317        Jamón cebo ibérico cortado a cuchillo        5.85       65.00
# 2318     Jamón bellota ibérico cortado a cuchillo       11.25      125.00
# 2319          Paleta curada lonchas Paletas Marpa        3.14       13.08
# 2320  Surtido de ibéricos La Hacienda del ibérico        5.95       29.75
# ...                                           ...         ...         ...
# 2318     Jamón bellota ibérico cortado a cuchillo       11.25      125.00
# 2317        Jamón cebo ibérico cortado a cuchillo        5.85       65.00
# 2316                     Jamón serrano Incarlopsa       32.00        4.76
# 2327            Paté de anchoa y salmón Hacendado        0.84        5.25
# 6970               Zumo de tomate picante Big Tom        1.65        6.60
#
#       price_iva
# 1            10
# 2317         10
# 2318         10
# 2319         10
# 2320         10
# ...         ...
# 2318         10
# 2317         10
# 2316         10
# 2327         10
# 6970         10
#
# [55768 rows x 11 columns]

# %%
categories_names = df.category_name.unique()

count = 0
for count, category_name in enumerate(categories_names):
    df_category = df[df.category_name == category_name]
    products_names = df_category.product_name.unique()

    fig, axs = plt.subplots(1)
    fig.suptitle(f'{category_name} Product\'s Prices Evolution')
    path_datasets_graph = f'graphs/{category_name}.svg'

    for product_name in products_names:
        if count == 20:
            break
        else:
            count == count + 1
            df_temp = df_category[df_category.product_name == product_name]
            x = df_temp.current_date
            y = df_temp.price_unit
            axs.plot( x, y, 'o--', alpha=0.3, label=product_name )

    plt.grid(axis='x', color='1.0')
    plt.title(category_name.capitalize())
    plt.legend()
    plt.xticks(rotation=90, ha='right')
    plt.plot()

    break
